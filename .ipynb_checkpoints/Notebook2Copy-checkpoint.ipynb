# %%
import pandas as pd
from fbprophet import Prophet
import numpy as np
from fbprophet.plot import add_changepoints_to_plot

# %%
import requests

POLONIEX_OHLCV_BASEURL = 'https://poloniex.com/public?command=returnChartData&currencyPair='

"""
https://poloniex.com/public?command=returnChartData&currencyPair=BTC_POT&start=1435699200&end=9999999999&period=14400

"""

def get_ohlcv_poloniex(pair='BTC_ETH', start=1435699200, end=9999999999, period=900):
    """
    returns ohlcv (open/high/low/close/volume) data for poloniex as pandas dataframe
    convert to unix timestamp using https://coderstoolbox.net/unixtimestamp/
    :param pair: str pair on poloniex
    :param start: int unix timestamp of beginning time
    :param end: int unix timestamp of ending time
    :param period: int candle width in seconds
    :return: pandas df of ohlcv data from poloniex for specified pair, times, and period
    """
    query = POLONIEX_OHLCV_BASEURL + pair + '&start=' + str(start) + '&end=' + str(end) + '&period=' + str(period)
    resp = requests.get(query)

    if resp.status_code != 200:
        raise requests.ApiError('GET /tasks/ {}'.format(resp.status_code))

    return pd.DataFrame(resp.json())

# %%
df = get_ohlcv_poloniex(pair='USDT_BTC', start=1483600958, end=9999999999, period=86400)
#one day in seconds
df = df[df.index % 4 == 0]
df['ds'] = pd.to_datetime(df['date'], unit='s')
df['y'] = df['weightedAverage']
df['log'] = df['weightedAverage'].apply(np.log)

# %%
df
# Out:
#            close        date         high          low         open  \
# 0     896.000000  1483660800  1024.880000   870.000000   998.800000
# 4     907.100000  1484006400   915.832309   898.000000   903.000000
# 8     817.477031  1484352000   836.040000   801.975002   827.000000
# 12    886.200000  1484697600   912.000000   850.000000   902.275793
# 16    924.119400  1485043200   939.060710   894.100100   925.706000
# 20    914.097671  1485388800   918.000000   892.667773   892.667773
# 24    918.000000  1485734400   920.000000   911.160522   913.000000
# 28   1015.043154  1486080000  1023.000000   989.000000  1007.996997
# 32   1052.000000  1486425600  1055.294000  1020.600000  1022.699993
# 36   1000.500000  1486771200  1010.000000   984.100000   994.000000
# 40   1014.835898  1487116800  1018.000000  1002.327215  1011.192931
# 44   1058.172622  1487462400  1066.197852  1045.000000  1059.219000
# 48   1188.000000  1487808000  1195.000000  1120.000000  1126.500000
# 52   1192.200000  1488153600  1199.000000  1171.376488  1179.000000
# 56   1287.950000  1488499200  1294.980000  1252.500000  1258.450000
# 60   1231.260000  1488844800  1282.000000  1169.055160  1274.693000
# 64   1175.010000  1489190400  1200.000000  1105.000000  1110.000000
# 68   1255.010000  1489536000  1267.510000  1241.590000  1247.950000
# 72   1015.100000  1489881600  1063.456000   965.000000   971.290660
# 76   1035.000000  1490227200  1057.006000  1002.520000  1034.823160
# 80   1040.250000  1490572800  1046.521042   957.673528   967.000000
# 84   1081.362951  1490918400  1095.000000  1036.798807  1040.599090
# 88   1143.908181  1491264000  1164.436090  1122.382041  1151.210203
# 92   1189.689038  1491609600  1207.770000  1172.400000  1197.590000
# 96   1227.000000  1491955200  1240.250000  1220.570000  1235.312144
# 100  1212.500000  1492300800  1217.000000  1190.000000  1193.948393
# 104  1306.650000  1492646400  1328.000000  1260.000000  1262.890000
# 108  1347.399011  1492992000  1357.760548  1325.955555  1352.193569
# 600    738.184914  5.185638e+06      7024.850065 2018-08-29  7024.850065
# 604   1087.337745  7.885339e+06      7251.968825 2018-09-02  7251.968825
# 608   1766.225804  1.137782e+07      6441.882187 2018-09-06  6441.882187
# 612    565.547307  3.558526e+06      6292.181793 2018-09-10  6292.181793
# 616     20.949883  1.357056e+05      6477.630859 2018-09-14  6477.630859
#
#           log
# 0    6.822927
# 4    6.811655
# 8    6.714098
# 12   6.780642
# 16   6.822621
# 20   6.810399
# 24   6.821082
# 28   6.914410
# 32   6.950844
# 36   6.907155
# 40   6.917814
# 44   6.961803
# 48   7.054717
# 52   7.079020
# 56   7.150974
# 60   7.115330
# 64   7.061335
# 68   7.131695
# 72   6.920665
# 76   6.944815
# 80   6.920544
# 84   6.965561
# 88   7.042509
# 92   7.081777
# 96   7.113678
# 100  7.097199
# 104  7.163319
# 108  7.202222
# 112  7.250109
# 116  7.351790
# ..        ...
# 500  9.041229
# 504  8.917320
# 508  8.900127
# 512  8.938351
# 516  8.935464
# 520  8.851374
# 524  8.777036
# 528  8.793675
# 532  8.730311
# 536  8.727429
# 540  8.761458
# 544  8.793976
# 548  8.816399
# 552  8.728684
# 556  8.788515
# 560  8.912457
# 564  9.003323
# 568  9.008407
# 572  8.930784
# 576  8.851825
# 580  8.769382
# 584  8.749230
# 588  8.776384
# 592  8.762373
# 596  8.811818
# 600  8.857209
# 604  8.889028
# 608  8.770576
# 612  8.747063
# 616  8.776110
#
# [155 rows x 11 columns]

# %%
df.plot(x='ds',y='y')

# %%
df.plot(x='ds',y='log')

# %% [markdown]
# ## Kurtosis & Skew

# %%
df.y.kurtosis()
# Out:
# 0.26197000417316785

# %% [markdown]
# A kurtosis this low (well below 3) means that there are less outliers than in a normal distribution.

# %%
df.y.skew()
# Out:
# 0.7358996002051634

# %% [markdown]
# A skew > 0 means that the graph is asymmetric with a tail on the right.

# %% [markdown]
# ## Prophet with various period values

# %%
m = Prophet(seasonality_mode='multiplicative')
m.fit(df)

future = m.make_future_dataframe(periods=30) 
future.tail()

forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
print("Linear Graphs")
fig1 = m.plot(forecast)
a = add_changepoints_to_plot(fig1.gca(), m, forecast)
fig2 = m.plot_components(forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /anaconda3/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Linear Graphs

# %%
m = Prophet()
m.fit(df)
future = m.make_future_dataframe(periods=1)
future.tail()
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
print("Linear Graphs")
fig1 = m.plot(forecast)
a = add_changepoints_to_plot(fig1.gca(), m, forecast)
#fig2 = m.plot_components(forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /anaconda3/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Linear Graphs

# %%
future = m.make_future_dataframe(periods=15)
future.tail()
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
print("Linear Graphs")
fig1 = m.plot(forecast)
a = add_changepoints_to_plot(fig1.gca(), m, forecast)
#fig2 = m.plot_components(forecast)
# Out:
# Linear Graphs

# %%
df['y'] = df['log']
m = Prophet()
m.fit(df)
future = m.make_future_dataframe(periods=30)
future.tail()
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
print("Log Graphs")
fig1 = m.plot(forecast)
a = add_changepoints_to_plot(fig1.gca(), m, forecast)
fig2 = m.plot_components(forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /anaconda3/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Log Graphs

# %%
m = Prophet()
m.fit(df)
future = m.make_future_dataframe(periods=1)
future.tail()
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
print("Log Graphs")
fig1 = m.plot(forecast)
a = add_changepoints_to_plot(fig1.gca(), m, forecast)
#fig2 = m.plot_components(forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /anaconda3/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Log Graphs

# %%
future = m.make_future_dataframe(periods=15)
future.tail()
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
print("Log Graphs")
fig1 = m.plot(forecast)
a = add_changepoints_to_plot(fig1.gca(), m, forecast)
#fig2 = m.plot_components(forecast)
# Out:
# Log Graphs

# %% [markdown]
# ## Change Changepoint Scale

# %%
m = Prophet(changepoint_prior_scale=0.5)
forecast = m.fit(df).predict(future)
fig = m.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), m, forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /anaconda3/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
m = Prophet(changepoint_prior_scale=0.01)
forecast = m.fit(df).predict(future)
fig = m.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), m, forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /anaconda3/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %% [markdown]
# ## Weekly Seasonality Analysis

# %% [markdown]
# May-September 2018

# %%
df2 = df.loc[500:600]
df2.plot(x='ds', y ='weightedAverage')
df2.plot(x='ds',y='log')

# %% [markdown]
# February - May 2018

# %%
df2 = df.loc[400:500]
df2.plot(x='ds', y ='weightedAverage')
df2.plot(x='ds',y='log')

# %% [markdown]
# November 2017- February 2018

# %%
df2 = df.loc[300:400]
df2.plot(x='ds', y ='weightedAverage')
df2.plot(x='ds', y ='log')
