# %%
import pandas as pd
import numpy as np
from scipy import stats
import scipy.cluster.hierarchy as hac
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import fcluster
from statsmodels.graphics.tsaplots import plot_pacf

from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist

from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import fcluster
# %matplotlib inline

# %%
import requests

POLONIEX_OHLCV_BASEURL = 'https://poloniex.com/public?command=returnChartData&currencyPair='

"""
https://poloniex.com/public?command=returnChartData&currencyPair=BTC_POT&start=1435699200&end=9999999999&period=14400

"""

def get_ohlcv_poloniex(pair='BTC_ETH', start=1435699200, end=9999999999, period=900):
    """
    returns ohlcv (open/high/low/close/volume) data for poloniex as pandas dataframe
    convert to unix timestamp using https://coderstoolbox.net/unixtimestamp/
    :param pair: str pair on poloniex
    :param start: int unix timestamp of beginning time
    :param end: int unix timestamp of ending time
    :param period: int candle width in seconds
    :return: pandas df of ohlcv data from poloniex for specified pair, times, and period
    """
    query = POLONIEX_OHLCV_BASEURL + pair + '&start=' + str(start) + '&end=' + str(end) + '&period=' + str(period)
    resp = requests.get(query)

    if resp.status_code != 200:
        raise requests.ApiError('GET /tasks/ {}'.format(resp.status_code))

    return pd.DataFrame(resp.json())

# %%
def fancy_dendrogram(*args, **kwargs):
    max_d = kwargs.pop('max_d', None)
    if max_d and 'color_threshold' not in kwargs:
        kwargs['color_threshold'] = max_d
    annotate_above = kwargs.pop('annotate_above', 0)

    ddata = dendrogram(*args, **kwargs)

    if not kwargs.get('no_plot', False):
        plt.title('Hierarchical Clustering Dendrogram (truncated)')
        plt.xlabel('sample index or (cluster size)')
        plt.ylabel('distance')
        for i, d, c in zip(ddata['icoord'], ddata['dcoord'], ddata['color_list']):
            x = 0.5 * sum(i[1:3])
            y = d[1]
            if y > annotate_above:
                plt.plot(x, y, 'o', c=c)
                plt.annotate("%.3g" % y, (x, y), xytext=(0, -5),
                             textcoords='offset points',
                             va='top', ha='center')
        if max_d:
            plt.axhline(y=max_d, c='k')
    return ddata

# %%
def clusters(timeSeries, pair):
    z_euclidean = hac.linkage(timeSeries, method='weighted', metric='euclidean')
    z_minkowski = hac.linkage(timeSeries, method='weighted', metric='minkowski')
    z_cityblock = hac.linkage(timeSeries, method='weighted', metric='cityblock')
    z_cosine = hac.linkage(timeSeries, method='weighted', metric='cosine')
    #z_correlation = hac.linkage(timeSeries, method='weighted', metric='correlation')
    
    autoCorrSeries = timeSeries.copy()
    lag=5
    autoCorrSeries['lagged'] = autoCorrSeries[pair].shift(lag)
    autoCorrSeries = autoCorrSeries.iloc[lag:]
    z_correlation = hac.linkage(autoCorrSeries, method='weighted', metric = 'correlation')
    
    p = 12
    max_d = .01 
    print("Euclidean")
    fancy_dendrogram(
        z_euclidean,
        truncate_mode='lastp',
        p=p,
        leaf_rotation=90.,
        leaf_font_size=12.,
        show_contracted=True,
        annotate_above=10,  # useful in small plots so annotations don't overlap
        max_d=max_d,
    )
    plt.show()

    print("Minkowski")
    fancy_dendrogram(
        z_minkowski,
        truncate_mode='lastp',
        p=p,
        leaf_rotation=90.,
        leaf_font_size=12.,
        show_contracted=True,
        annotate_above=10,  # useful in small plots so annotations don't overlap
        max_d=max_d,
    )
    plt.show()

    print("Cityblock")
    fancy_dendrogram(
        z_cityblock,
        truncate_mode='lastp',
        p=p,
        leaf_rotation=90.,
        leaf_font_size=12.,
        show_contracted=True,
        annotate_above=10,  # useful in small plots so annotations don't overlap
        max_d=max_d,
    )
    plt.show()

    print("Cosine")
    fancy_dendrogram(
        z_cosine,
        truncate_mode='lastp',
        p=p,
        leaf_rotation=90.,
        leaf_font_size=12.,
        show_contracted=True,
        annotate_above=10,  # useful in small plots so annotations don't overlap
        max_d=max_d,
    )
    plt.show()

    print("Correlation")
    fancy_dendrogram(
         z_correlation,
         truncate_mode='lastp',
         p=p,
         leaf_rotation=90.,
         leaf_font_size=12.,
         show_contracted=True,
         annotate_above=10,  # useful in small plots so annotations don't overlap
     )
    plt.show()

    print("Cophenetic Correlation Coefficients")
    print("")
    c, coph_dists = cophenet(z_euclidean, pdist(timeSeries))
    print("Euclidean Cophenetic Correlation Coefficient: " + str(c))
    c, coph_dists = cophenet(z_minkowski, pdist(timeSeries))
    print("Minkowski Cophenetic Correlation Coefficient: " + str(c))
    c, coph_dists = cophenet(z_cityblock, pdist(timeSeries))
    print("Cityblock Cophenetic Correlation Coefficient: " + str(c))
    c, coph_dists = cophenet(z_cosine, pdist(timeSeries))
    print("Cosine Cophenetic Correlation Coefficient: " + str(c))
    c, coph_dists = cophenet(z_correlation, pdist(autoCorrSeries))
    print("Correlation Cophenetic Correlation Coefficient: " + str(c))
    
    print("Euclidean Clusters")
    clusters = fcluster(z_euclidean, max_d, criterion='distance')
    plt.figure(figsize=(10, 8))
    plt.scatter(timeSeries[pair], timeSeries[pair], c=clusters, cmap='prism')  
    plt.show()
    
    print("Minkowski Clusters")
    clusters = fcluster(z_minkowski, max_d, criterion='distance')
    plt.figure(figsize=(10, 8))
    plt.scatter(timeSeries[pair], timeSeries[pair], c=clusters, cmap='prism')  
    plt.show()
        
    print("Cityblock Clusters")
    clusters = fcluster(z_cityblock, max_d, criterion='distance')
    plt.figure(figsize=(10, 8))
    plt.scatter(timeSeries[pair], timeSeries[pair], c=clusters, cmap='prism')  
    plt.show()
    
    print("Cosine Clusters")
    clusters = fcluster(z_cosine, max_d, criterion='distance')
    plt.figure(figsize=(10, 8))
    plt.scatter(timeSeries[pair], timeSeries[pair], c=clusters, cmap='prism')  
    plt.show()
    
    print("Correlation Clusters")
    clusters = fcluster(z_correlation, max_d, criterion='distance')
    plt.figure(figsize=(10, 8))
    plt.scatter(autoCorrSeries[pair], autoCorrSeries["lagged"], c=clusters, cmap='prism')  
    plt.show()

# %%
#def plot_partial_lag(timeSeries, lag):
 #   plot_pacf(timeSeries, lags=lag)
  #  plt.show()

# %%
#for pair in ['USDT_BTC','USDT_ETH', 'USDT_LTC', 'USDT_DASH', 'BTC_ETH', 'BTC_LTC', 'BTC_DASH']:
pair = 'USDT_BTC'
timeSeries = pd.DataFrame()
df = get_ohlcv_poloniex(pair=pair, start=1483600958, end=9999999999, period=86400)
df['pct_change'] = df['weightedAverage'].pct_change()
df['log_ret'] = np.log(df['weightedAverage']) - np.log(df['weightedAverage'].shift(1))
df[pair] = df['log_ret']
df = pd.DataFrame(df[pair])
timeSeries = pd.concat([timeSeries,df], axis=1)
timeSeries = timeSeries.iloc[1:]
print(pair)
clusters(timeSeries, pair)
#plot_partial_lag(timeSeries, 50)
# Out:
# USDT_BTC
# Euclidean
# Minkowski
# Cityblock
# Cosine
# Correlation
# Cophenetic Correlation Coefficients
#
# Euclidean Cophenetic Correlation Coefficient: 0.6052929009156995
# Minkowski Cophenetic Correlation Coefficient: 0.6052929009156995
# Cityblock Cophenetic Correlation Coefficient: 0.6052929009156995
# Cosine Cophenetic Correlation Coefficient: 0.4285706356504065
# Correlation Cophenetic Correlation Coefficient: 0.2563218267049188
# Euclidean Clusters
# Minkowski Clusters
# Cityblock Clusters
# Cosine Clusters
# Correlation Clusters

# %%
pair = 'USDT_ETH'
timeSeries = pd.DataFrame()
df = get_ohlcv_poloniex(pair=pair, start=1483600958, end=9999999999, period=86400)
df = df[df.index % 7 == 0]
df['pct_change'] = df['weightedAverage'].pct_change()
df['log_ret'] = np.log(df['weightedAverage']) - np.log(df['weightedAverage'].shift(1))
df[pair] = df['log_ret']
df = pd.DataFrame(df[pair])
timeSeries = pd.concat([timeSeries,df], axis=1)
timeSeries = timeSeries.iloc[1:]
print(pair)
clusters(timeSeries, pair)
# Out:
# USDT_ETH
# Euclidean
# Minkowski
# Cityblock
# Cosine
# Correlation
# Cophenetic Correlation Coefficients
#
# Euclidean Cophenetic Correlation Coefficient: 0.7376624157234662
# Minkowski Cophenetic Correlation Coefficient: 0.7376624157234662
# Cityblock Cophenetic Correlation Coefficient: 0.7376624157234662
# Cosine Cophenetic Correlation Coefficient: 0.42149458312838045
# Correlation Cophenetic Correlation Coefficient: 0.29281415595236376
# Euclidean Clusters
# Minkowski Clusters
# Cityblock Clusters
# Cosine Clusters
# Correlation Clusters

# %%
pair = 'USDT_LTC'
timeSeries = pd.DataFrame()
df = get_ohlcv_poloniex(pair=pair, start=1483600958, end=9999999999, period=86400)
df = df[df.index % 7 == 0]
df['pct_change'] = df['weightedAverage'].pct_change()
df['log_ret'] = np.log(df['weightedAverage']) - np.log(df['weightedAverage'].shift(1))
df[pair] = df['log_ret']
df = pd.DataFrame(df[pair])
timeSeries = pd.concat([timeSeries,df], axis=1)
timeSeries = timeSeries.iloc[1:]
print(pair)
clusters(timeSeries, pair)
# Out:
# USDT_LTC
# Euclidean
# Minkowski
# Cityblock
# Cosine
# Correlation
# Cophenetic Correlation Coefficients
#
# Euclidean Cophenetic Correlation Coefficient: 0.836257951262483
# Minkowski Cophenetic Correlation Coefficient: 0.836257951262483
# Cityblock Cophenetic Correlation Coefficient: 0.836257951262483
# Cosine Cophenetic Correlation Coefficient: 0.31687977330309164
# Correlation Cophenetic Correlation Coefficient: 0.2148919104882666
# Euclidean Clusters
# Minkowski Clusters
# Cityblock Clusters
# Cosine Clusters
# Correlation Clusters

# %%
pair = 'USDT_DASH'
timeSeries = pd.DataFrame()
df = get_ohlcv_poloniex(pair=pair, start=1483600958, end=9999999999, period=86400)
df = df[df.index % 7 == 0]
df['pct_change'] = df['weightedAverage'].pct_change()
df['log_ret'] = np.log(df['weightedAverage']) - np.log(df['weightedAverage'].shift(1))
df[pair] = df['log_ret']
df = pd.DataFrame(df[pair])
timeSeries = pd.concat([timeSeries,df], axis=1)
timeSeries = timeSeries.iloc[1:]
print(pair)
clusters(timeSeries, pair)
# Out:
# USDT_DASH
# Euclidean
# Minkowski
# Cityblock
# Cosine
# Correlation
# Cophenetic Correlation Coefficients
#
# Euclidean Cophenetic Correlation Coefficient: 0.600668004307052
# Minkowski Cophenetic Correlation Coefficient: 0.600668004307052
# Cityblock Cophenetic Correlation Coefficient: 0.600668004307052
# Cosine Cophenetic Correlation Coefficient: 0.5320913446244276
# Correlation Cophenetic Correlation Coefficient: 0.33243912073766785
# Euclidean Clusters
# Minkowski Clusters
# Cityblock Clusters
# Cosine Clusters
# Correlation Clusters

# %%
pair = 'BTC_ETH'
timeSeries = pd.DataFrame()
df = get_ohlcv_poloniex(pair=pair, start=1483600958, end=9999999999, period=86400)
df = df[df.index % 7 == 0]
df['pct_change'] = df['weightedAverage'].pct_change()
df['log_ret'] = np.log(df['weightedAverage']) - np.log(df['weightedAverage'].shift(1))
df[pair] = df['log_ret']
df = pd.DataFrame(df[pair])
timeSeries = pd.concat([timeSeries,df], axis=1)
timeSeries = timeSeries.iloc[1:]
print(pair)
clusters(timeSeries, pair)
# Out:
# BTC_ETH
# Euclidean
# Minkowski
# Cityblock
# Cosine
# Correlation
# Cophenetic Correlation Coefficients
#
# Euclidean Cophenetic Correlation Coefficient: 0.8000783908499461
# Minkowski Cophenetic Correlation Coefficient: 0.8000783908499461
# Cityblock Cophenetic Correlation Coefficient: 0.8000783908499461
# Cosine Cophenetic Correlation Coefficient: 0.36007894089022424
# Correlation Cophenetic Correlation Coefficient: 0.21476644901066724
# Euclidean Clusters
# Minkowski Clusters
# Cityblock Clusters
# Cosine Clusters
# Correlation Clusters

# %%
pair = 'BTC_ETH'
timeSeries = pd.DataFrame()
df = get_ohlcv_poloniex(pair=pair, start=1483600958, end=9999999999, period=86400)
df = df[df.index % 7 == 0]
df['pct_change'] = df['weightedAverage'].pct_change()
df['log_ret'] = np.log(df['weightedAverage']) - np.log(df['weightedAverage'].shift(1))
df[pair] = df['log_ret']
df = pd.DataFrame(df[pair])
timeSeries = pd.concat([timeSeries,df], axis=1)
timeSeries = timeSeries.iloc[1:]
print(pair)
clusters(timeSeries, pair)
# Out:
# BTC_ETH
# Euclidean
# Minkowski
# Cityblock
# Cosine
# Correlation
# Cophenetic Correlation Coefficients
#
# Euclidean Cophenetic Correlation Coefficient: 0.8000783908499461
# Minkowski Cophenetic Correlation Coefficient: 0.8000783908499461
# Cityblock Cophenetic Correlation Coefficient: 0.8000783908499461
# Cosine Cophenetic Correlation Coefficient: 0.36007894089022424
# Correlation Cophenetic Correlation Coefficient: 0.21476644901066724
# Euclidean Clusters
# Minkowski Clusters
# Cityblock Clusters
# Cosine Clusters
# Correlation Clusters

# %%
pair = 'BTC_LTC'
timeSeries = pd.DataFrame()
df = get_ohlcv_poloniex(pair=pair, start=1483600958, end=9999999999, period=86400)
df = df[df.index % 7 == 0]
df['pct_change'] = df['weightedAverage'].pct_change()
df['log_ret'] = np.log(df['weightedAverage']) - np.log(df['weightedAverage'].shift(1))
df[pair] = df['log_ret']
df = pd.DataFrame(df[pair])
timeSeries = pd.concat([timeSeries,df], axis=1)
timeSeries = timeSeries.iloc[1:]
print(pair)
clusters(timeSeries, pair)
# Out:
# BTC_LTC
# Euclidean
# Minkowski
# Cityblock
# Cosine
# Correlation
# Cophenetic Correlation Coefficients
#
# Euclidean Cophenetic Correlation Coefficient: 0.8415295777487901
# Minkowski Cophenetic Correlation Coefficient: 0.8415295777487901
# Cityblock Cophenetic Correlation Coefficient: 0.8415295777487901
# Cosine Cophenetic Correlation Coefficient: 0.40399377082281096
# Correlation Cophenetic Correlation Coefficient: 0.1991003525247787
# Euclidean Clusters
# Minkowski Clusters
# Cityblock Clusters
# Cosine Clusters
# Correlation Clusters

# %%
pair = 'BTC_DASH'
timeSeries = pd.DataFrame()
df = get_ohlcv_poloniex(pair=pair, start=1483600958, end=9999999999, period=86400)
df = df[df.index % 7 == 0]
df['pct_change'] = df['weightedAverage'].pct_change()
df['log_ret'] = np.log(df['weightedAverage']) - np.log(df['weightedAverage'].shift(1))
df[pair] = df['log_ret']
df = pd.DataFrame(df[pair])
timeSeries = pd.concat([timeSeries,df], axis=1)
timeSeries = timeSeries.iloc[1:]
print(pair)
clusters(timeSeries, pair)
# Out:
# BTC_DASH
# Euclidean
# Minkowski
# Cityblock
# Cosine
# Correlation
# Cophenetic Correlation Coefficients
#
# Euclidean Cophenetic Correlation Coefficient: 0.5321664319436715
# Minkowski Cophenetic Correlation Coefficient: 0.5321664319436715
# Cityblock Cophenetic Correlation Coefficient: 0.5321664319436715
# Cosine Cophenetic Correlation Coefficient: 0.3860516500896607
# Correlation Cophenetic Correlation Coefficient: 0.24035548472641927
# Euclidean Clusters
# Minkowski Clusters
# Cityblock Clusters
# Cosine Clusters
# Correlation Clusters
