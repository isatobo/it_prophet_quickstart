# %%
import pandas as pd
from fbprophet import Prophet
import numpy as np
from fbprophet.plot import add_changepoints_to_plot

# %%
import requests

POLONIEX_OHLCV_BASEURL = 'https://poloniex.com/public?command=returnChartData&currencyPair='

"""
https://poloniex.com/public?command=returnChartData&currencyPair=BTC_POT&start=1435699200&end=9999999999&period=14400

"""

def get_ohlcv_poloniex(pair='BTC_ETH', start=1435699200, end=9999999999, period=900):
    """
    returns ohlcv (open/high/low/close/volume) data for poloniex as pandas dataframe
    convert to unix timestamp using https://coderstoolbox.net/unixtimestamp/
    :param pair: str pair on poloniex
    :param start: int unix timestamp of beginning time
    :param end: int unix timestamp of ending time
    :param period: int candle width in seconds
    :return: pandas df of ohlcv data from poloniex for specified pair, times, and period
    """
    query = POLONIEX_OHLCV_BASEURL + pair + '&start=' + str(start) + '&end=' + str(end) + '&period=' + str(period)
    resp = requests.get(query)

    if resp.status_code != 200:
        raise requests.ApiError('GET /tasks/ {}'.format(resp.status_code))

    return pd.DataFrame(resp.json())

# %%
df = get_ohlcv_poloniex(pair='USDT_BTC', start=1483600958, end=9999999999, period=86400)
#one day in seconds
df['ds'] = pd.to_datetime(df['date'], unit='s')
df['y'] = df['weightedAverage']
df['log'] = df['weightedAverage'].apply(np.log)

# %%
df
# Out:
#            close        date         high          low         open  \
# 0     896.000000  1483660800  1024.880000   870.000000   998.800000
# 1     907.190479  1483747200   910.827519   818.459718   896.000000
# 2     916.000000  1483833600   939.659554   891.100000   907.000000
# 3     902.000000  1483920000   916.418330   880.000000   916.418330
# 4     907.100000  1484006400   915.832309   898.000000   903.000000
# 5     781.811601  1484092800   927.828104   751.000000   907.929452
# 6     803.695279  1484179200   832.879900   752.010200   781.851601
# 7     826.000000  1484265600   830.592908   776.028995   805.000004
# 8     817.477031  1484352000   836.040000   801.975002   827.000000
# 9     818.701245  1484438400   823.498000   805.000000   817.477031
# 10    829.000000  1484524800   834.156805   816.000000   818.762000
# 11    902.700001  1484611200   908.530178   827.759709   829.000000
# 12    886.200000  1484697600   912.000000   850.000000   902.275793
# 13    900.232400  1484784000   906.999999   883.300000   886.200001
# 14    895.000000  1484870400   902.430000   882.543200   900.300000
# 15    925.706000  1484956800   928.518494   894.000000   895.099711
# 16    924.119400  1485043200   939.060710   894.100100   925.706000
# 17    912.221650  1485129600   927.235100   912.221650   923.990000
# 18    885.000000  1485216000   923.000000   884.281000   912.221650
# 19    892.667773  1485302400   899.990000   882.080000   885.100000
# 20    914.097671  1485388800   918.000000   892.667773   892.667773
# 21    917.027451  1485475200   921.650000   907.800000   916.000000
# 22    918.586004  1485561600   926.000000   909.987300   917.436775
# 23    914.999800  1485648000   923.000000   911.860406   918.990000
# 24    918.000000  1485734400   920.000000   911.160522   913.000000
# 25    967.121764  1485820800   970.000000   916.750000   919.119187
# 26    983.000000  1485907200   986.000000   955.400000   967.755822
# 27   1007.996997  1485993600  1009.999999   968.277698   983.000000
# 28   1015.043154  1486080000  1023.000000   989.000000  1007.996997
# 615   729.524198  4.710302e+06      6456.677408 2018-09-13  6456.677408
# 616   813.653568  5.278847e+06      6487.830986 2018-09-14  6487.830986
# 617   378.183861  2.464325e+06      6516.209888 2018-09-15  6516.209888
# 618   549.008128  3.547223e+06      6461.148268 2018-09-16  6461.148268
# 619    33.218354  2.165668e+05      6519.492466 2018-09-17  6519.492466
#
#           log
# 0    6.822927
# 1    6.763873
# 2    6.822124
# 3    6.797440
# 4    6.811655
# 5    6.711812
# 6    6.668271
# 7    6.694107
# 8    6.714098
# 9    6.702484
# 10   6.716966
# 11   6.782425
# 12   6.780642
# 13   6.796979
# 14   6.796500
# 15   6.822454
# 16   6.822621
# 17   6.823441
# 18   6.804724
# 19   6.792980
# 20   6.810399
# 21   6.820224
# 22   6.824060
# 23   6.821810
# 24   6.821082
# 25   6.852864
# 26   6.874549
# 27   6.903108
# 28   6.914410
# 29   6.931092
# ..        ...
# 590  8.767643
# 591  8.759573
# 592  8.762373
# 593  8.791779
# 594  8.770825
# 595  8.791450
# 596  8.811818
# 597  8.805068
# 598  8.820372
# 599  8.855542
# 600  8.857209
# 601  8.840623
# 602  8.854221
# 603  8.874808
# 604  8.889028
# 605  8.890689
# 606  8.901764
# 607  8.855844
# 608  8.770576
# 609  8.770953
# 610  8.740832
# 611  8.752122
# 612  8.747063
# 613  8.746058
# 614  8.743382
# 615  8.772870
# 616  8.777684
# 617  8.782048
# 618  8.773562
# 619  8.782552
#
# [620 rows x 11 columns]

# %%
df.plot(x='ds',y='y')

# %%
df.plot(x='ds',y='log')

# %% [markdown]
# ## Kurtosis & Skew

# %%
df.y.kurtosis()
# Out:
# 0.17278925109541232

# %% [markdown]
# A kurtosis this low (well below 3) means that there are less outliers than in a normal distribution.

# %%
df.y.skew()
# Out:
# 0.7097084095509317

# %% [markdown]
# A skew > 0 means that the graph is asymmetric with a tail on the right.

# %% [markdown]
# ## Prophet with various period values

# %%
m = Prophet(seasonality_mode='multiplicative')
m.fit(df)

future = m.make_future_dataframe(periods=30) 
future.tail()

forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
print("Linear Graphs")
fig1 = m.plot(forecast)
a = add_changepoints_to_plot(fig1.gca(), m, forecast)
fig2 = m.plot_components(forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /anaconda3/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Linear Graphs

# %%
m = Prophet()
m.fit(df)
future = m.make_future_dataframe(periods=1)
future.tail()
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
print("Linear Graphs")
fig1 = m.plot(forecast)
a = add_changepoints_to_plot(fig1.gca(), m, forecast)
#fig2 = m.plot_components(forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /anaconda3/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Linear Graphs

# %%
future = m.make_future_dataframe(periods=15)
future.tail()
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
print("Linear Graphs")
fig1 = m.plot(forecast)
a = add_changepoints_to_plot(fig1.gca(), m, forecast)
#fig2 = m.plot_components(forecast)
# Out:
# Linear Graphs

# %%
df['y'] = df['log']
m = Prophet()
m.fit(df)
future = m.make_future_dataframe(periods=30)
future.tail()
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
print("Log Graphs")
fig1 = m.plot(forecast)
a = add_changepoints_to_plot(fig1.gca(), m, forecast)
fig2 = m.plot_components(forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /anaconda3/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Log Graphs

# %%
m = Prophet()
m.fit(df)
future = m.make_future_dataframe(periods=1)
future.tail()
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
print("Log Graphs")
fig1 = m.plot(forecast)
a = add_changepoints_to_plot(fig1.gca(), m, forecast)
#fig2 = m.plot_components(forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /anaconda3/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):
# Log Graphs

# %%
future = m.make_future_dataframe(periods=15)
future.tail()
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
print("Log Graphs")
fig1 = m.plot(forecast)
a = add_changepoints_to_plot(fig1.gca(), m, forecast)
#fig2 = m.plot_components(forecast)
# Out:
# Log Graphs

# %% [markdown]
# ## Change Changepoint Scale

# %%
m = Prophet(changepoint_prior_scale=0.5)
forecast = m.fit(df).predict(future)
fig = m.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), m, forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /anaconda3/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
m = Prophet(changepoint_prior_scale=0.01)
forecast = m.fit(df).predict(future)
fig = m.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), m, forecast)
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /anaconda3/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %% [markdown]
# ## Weekly Seasonality Analysis

# %% [markdown]
# May-September 2018

# %%
df2 = df.loc[500:600]
df2.plot(x='ds', y ='weightedAverage')
df2.plot(x='ds',y='log')

# %% [markdown]
# February - May 2018

# %%
df2 = df.loc[400:500]
df2.plot(x='ds', y ='weightedAverage')
df2.plot(x='ds',y='log')

# %% [markdown]
# November 2017- February 2018

# %%
df2 = df.loc[300:400]
df2.plot(x='ds', y ='weightedAverage')
df2.plot(x='ds', y ='log')
